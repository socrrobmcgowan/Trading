# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import json
import datetime


token = 'Tsk_b8dfd6ba7eaa4917bc45e4c45c46ef0d'
api_token = 'sk_f491c9326e6a4b79a7ed5b1689c178f3'



today = datetime.datetime.today()
today_date = str(today.month)+'/'+str(today.day)+'/'+str(today.year)
yesterday = today - datetime.timedelta(days = 1)
day= str(today.day).zfill(2)
month = str(today.month).zfill(2)
year = today.year
last_year = int(year)-1

symbol_dict = {}


symbol = 'AAPL'

symbol_dict = {}

def get_stock_data_iex(symbol):


    def get_data(symbol):
        
        r = requests.get(f'https://sandbox.iexapis.com/stable/stock/{symbol}/batch?types=balance-sheet,quote,company,chart&range=1y&token={token}')
        pr = json.loads(r.content)
        df = pd.DataFrame(pr['chart'])
        df.set_index('date', inplace = True)

        return df
    
    try:
        df = get_data(symbol)
        df['close'] = df['close'].astype(float)
        df['volume'] = df['volume'].astype(float)
        df['fast'] = df['close'].ewm(span=12).mean()
        df['slow'] = df['close'].ewm(span=26).mean()
        df['macd'] = df['fast']-df['slow']
        df['signal'] = df['macd'].ewm(span=9).mean()
        df['200MA'] = df['close'].rolling(200).mean()
        df['50MA'] = df['close'].rolling(50).mean()
        df['100MA'] = df['close'].rolling(100).mean()
        df['10MA'] = df['close'].rolling(10).mean()
        df['20MA'] = df['close'].rolling(20).mean()
        df['BB_20_upper_2std'] = (df['close'].rolling(20).std()*2) + df['20MA']
        df['BB_20_lower_2std'] = df['20MA'] - (df['close'].rolling(20).std()*2)


        symbol_dict[symbol] = {}
        symbol_dict[symbol]['historical_data'] = df
#         symbol_dict[symbol]['close'] = df.iloc[-1]['close']
#         symbol_dict[symbol]['10MA'] = df.iloc[-1]['10MA']
#         symbol_dict[symbol]['20MA'] = df.iloc[-1]['20MA']
#         symbol_dict[symbol]['50MA'] = df.iloc[-1]['50MA']
#         symbol_dict[symbol]['100MA'] = df.iloc[-1]['100MA']
#         symbol_dict[symbol]['200MA'] = df.iloc[-1]['200MA']
#         symbol_dict[symbol]['fast'] = df.iloc[-1]['fast']
#         symbol_dict[symbol]['slow'] = df.iloc[-1]['slow']
#         symbol_dict[symbol]['signal'] = df.iloc[-1]['signal']
#         symbol_dict[symbol]['macd'] = df.iloc[-1]['macd']
#         symbol_dict[symbol]['yearLow'] = df['close'].min()
#         symbol_dict[symbol]['yearHigh'] = df['close'].max()

#         try:
#             symbol_dict[symbol]['name'] = fin_dict['context']['dispatcher']['stores']['QuoteSummaryStore']['quoteType']['longName']
#         except:
#             symbol_dict[symbol]['name'] = 'N/A'
#         try:
#             symbol_dict[symbol]['dividend_yield'] = round(float(fin_dict['context']['dispatcher']['stores']['QuoteSummaryStore']['summaryDetail']['dividendYield']['raw'])*100,2)
#         except:
#             symbol_dict[symbol]['dividend_yield'] = "N/A"
#         try:
#             symbol_dict[symbol]['beta'] = float(fin_dict['context']['dispatcher']['stores']['QuoteSummaryStore']['summaryDetail']['beta']['fmt'])
#         except:
#             symbol_dict[symbol]['beta'] = "N/A"
#         try:
#             symbol_dict[symbol]['pe_ratio'] = float(fin_dict['context']['dispatcher']['stores']['QuoteSummaryStore']['summaryDetail']['trailingPE']['fmt'])
#         except:
#             try:
#                 symbol_dict[symbol]['pe_ratio'] = float(fin_dict['context']['dispatcher']['stores']['QuoteSummaryStore']['summaryDetail']['forwardPE']['fmt'])
#             except:
#                 symbol_dict[symbol]['pe_ratio'] = "N/A"
#         try:
#             symbol_dict[symbol]['average_volume'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['summaryDetail']['averageVolume']['longFmt']
#         except:
#             symbol_dict[symbol]['average_volume'] = "N/A"
#         try:
#             symbol_dict[symbol]['price_to_book'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['priceToBook']['fmt'])
#         except:
#             symbol_dict[symbol]['price_to_book'] = "N/A"
#         try:
#             symbol_dict[symbol]['enterprise_to_revenue'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['enterpriseToRevenue']['fmt'])
#         except:
#             symbol_dict[symbol]['enterprise_to_revenue'] = "N/A"
#         try:
#             symbol_dict[symbol]['enterprise_to_ebita'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['enterpriseToEbitda']['fmt'])
#         except:
#             symbol_dict[symbol]['enterprise_to_ebita'] = "N/A"
#         try:
#             symbol_dict[symbol]['shares_outstanding'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['sharesOutstanding']['longFmt']
#         except:
#             symbol_dict[symbol]['shares_outstanding'] = "N/A"
#         try:
#             symbol_dict[symbol]['percent_institutions'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['heldPercentInstitutions']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['percent_institutions'] = "N/A"
#         try:
#             symbol_dict[symbol]['percent_insiders'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['heldPercentInsiders']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['percent_insiders'] = "N/A"
#         try:
#             symbol_dict[symbol]['short_ratio'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['shortRatio']['fmt'])
#         except:
#             symbol_dict[symbol]['short_ratio'] = "N/A"
#         try:
#             symbol_dict[symbol]['float_shares'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['floatShares']['longFmt']
#         except:
#             symbol_dict[symbol]['float_shares'] = "N/A"
#         try:
#             symbol_dict[symbol]['enterprise_value'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['enterpriseValue']['longFmt']
#         except:
#             symbol_dict[symbol]['enterprise_value'] = "N/A"
#         try:
#             symbol_dict[symbol]['earnings_quarterly_growth'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['earningsQuarterlyGrowth']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['earnings_quarterly_growth'] = "N/A"
#         try:
#             symbol_dict[symbol]['short_of_float'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['defaultKeyStatistics']['shortPercentOfFloat']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['short_of_float'] = "N/A"
#         try:
#             symbol_dict[symbol]['sector'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['summaryProfile']['sector']
#         except:
#             symbol_dict[symbol]['sector'] = "N/A"
#         try:
#             symbol_dict[symbol]['business_summary'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['summaryProfile']['longBusinessSummary']
#         except:
#             symbol_dict[symbol]['business_summary'] = "N/A"
#         try:
#             symbol_dict[symbol]['last_eps'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['earnings']['earningsChart']['quarterly'][-1]['actual']['fmt'])
#         except:
#             symbol_dict[symbol]['last_eps'] = "N/A"
#         try:
#             symbol_dict[symbol]['estimate_eps'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['earnings']['earningsChart']['currentQuarterEstimate']['fmt'])
#         except:
#             symbol_dict[symbol]['estimate_eps'] = "N/A"
#         try:
#             symbol_dict[symbol]['earnings_date'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['earnings']['earningsChart']['earningsDate'][0]['fmt']
#         except:
#             symbol_dict[symbol]['earnings_date'] = "N/A"
#         try:
#             symbol_dict[symbol]['ebitda_margin'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['ebitdaMargins']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['ebitda_margin'] = "N/A"
#         try:
#             symbol_dict[symbol]['profit_margin'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['profitMargins']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['profit_margin'] = "N/A"
#         try:
#             symbol_dict[symbol]['gross_margin'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['grossMargins']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['gross_margin'] = "N/A"
#         try:
#             symbol_dict[symbol]['operating_cashflow'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['operatingCashflow']['longFmt']
#         except:
#             symbol_dict[symbol]['operating_cashflow'] = "N/A"
#         try:
#             symbol_dict[symbol]['revenue_growth'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['revenueGrowth']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['revenue_growth'] = "N/A"
#         try:
#             symbol_dict[symbol]['operating_margin'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['operatingMargins']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['operating_margin'] = "N/A"
#         try:
#             symbol_dict[symbol]['ebitda'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['ebitda']['longFmt']
#         except:
#             symbol_dict[symbol]['ebitda'] = "N/A"
#         try:
#             symbol_dict[symbol]['gross_profits'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['grossProfits']['longFmt']
#         except:
#             symbol_dict[symbol]['gross_profits'] = "N/A"
#         try:
#             symbol_dict[symbol]['free_cashflow'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['freeCashflow']['longFmt']
#         except:
#             symbol_dict[symbol]['free_cashflow'] = "N/A"
#         try:
#             symbol_dict[symbol]['earnings_growth'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['earningsGrowth']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['earnings_growth'] = "N/A"
#         try:
#             symbol_dict[symbol]['current_ratio'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['currentRatio']['fmt'])
#         except:
#             symbol_dict[symbol]['current_ratio'] = "N/A"
#         try:
#             symbol_dict[symbol]['return_on_assets'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['returnOnAssets']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['return_on_assets'] = "N/A"
#         try:
#             symbol_dict[symbol]['debt_to_equity'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['debtToEquity']['fmt'])
#         except:
#             symbol_dict[symbol]['debt_to_equity'] = "N/A"
#         try:
#             symbol_dict[symbol]['return_on_equity'] = round(float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['returnOnEquity']['raw']*100),2)
#         except:
#             symbol_dict[symbol]['return_on_equity'] = "N/A"
#         try:
#             symbol_dict[symbol]['total_cash'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['totalCash']['longFmt']
#         except:
#             symbol_dict[symbol]['total_cash'] = "N/A"
#         try:
#             symbol_dict[symbol]['total_debt'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['totalDebt']['longFmt']
#         except:
#             symbol_dict[symbol]['total_debt'] = "N/A"
#         try:
#             symbol_dict[symbol]['total_revenue'] = fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['totalRevenue']['longFmt']
#         except:
#             symbol_dict[symbol]['total_revenue'] = "N/A"
#         try:
#             symbol_dict[symbol]['total_cash_share'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['totalCashPerShare']['fmt'])
#         except:
#             symbol_dict[symbol]['total_cash_share'] = "N/A"
#         try:
#             symbol_dict[symbol]['revenue_per_share'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['revenuePerShare']['fmt'])
#         except:
#             symbol_dict[symbol]['revenue_per_share'] = "N/A"
#         try:
#             symbol_dict[symbol]['quick_ratio'] = float(fin_dict_adv['context']['dispatcher']['stores']['QuoteSummaryStore']['financialData']['quickRatio']['fmt'])
#         except:
#             symbol_dict[symbol]['quick_ratio'] = "N/A"


    except:
        next

    return symbol_dict

# %%
get_stock_data_iex('AAPL')
# Out:
# {'AAPL': {'historical_data':             change  changeOverTime  changePercent   close    high       label  \
#   date
#   2019-02-15    0.00        0.000000         0.0000  172.04  176.10  Feb 15, 19
#   2019-02-19    0.52        0.003135         0.3015  176.12  176.96  Feb 19, 19
#   2019-02-20    1.10        0.009487         0.6599  172.20  180.97  Feb 20, 19
#   2019-02-21   -0.99        0.003767        -0.5703  174.58  175.23  Feb 21, 19
#   2019-02-22    2.00        0.015418         1.1177  174.82  178.00  Feb 22, 19
#   2019-02-25    1.26        0.022956         0.7464  179.96  176.77  Feb 25, 19
#   2019-02-26    0.10        0.023959         0.0584  174.34  181.60  Feb 26, 19
#   2019-02-27    0.56        0.027397         0.3209  177.70  175.00  Feb 27, 19
#   2019-02-28   -1.78        0.016383        -0.9885  181.74  182.96  Feb 28, 19
#   2019-03-01    1.85        0.027438         1.0834  181.43  180.55   Mar 1, 19
# ...

# %%
today_date = f'{year}-{month}-{day}'
today_date
# Out:
# '2020-02-18'

# %%
r = requests.get(f'https://sandbox.iexapis.com/stable/stock/{symbol}/batch?types=advanced-stats,financials,earnings,dividends,cash-flow,balance-sheet,quote,company,chart&range=1y&token={token}')
pr = json.loads(r.content)
pr
# Out:
# {'advanced-stats': {'week52change': 0.9281,
#   'week52high': 329.64,
#   'week52low': 174.13,
#   'marketcap': 1442855906391,
#   'employees': 138083,
#   'day200MovingAvg': 240.46,
#   'day50MovingAvg': 303.24,
#   'float': 4423357759,
#   'avg10Volume': 29542293.2,
#   'avg30Volume': 34304899,
#   'ttmEPS': 13.0023,
#   'ttmDividendRate': 3.15,
#   'companyName': 'Apple, Inc.',
#   'sharesOutstanding': 4517861620,
#   'maxChangePercent': 325.0217,
#   'year5ChangePercent': 1.7921,
#   'year2ChangePercent': 1.0868,
#   'year1ChangePercent': 0.919,
#   'ytdChangePercent': 0.1011,
#   'month6ChangePercent': 0.6519,
#   'month3ChangePercent': 0.2599,
#   'month1ChangePercent': 0.093,
#   'day30ChangePercent': 0.093,
#   'day5ChangePercent': -0.0071,
#   'nextDividendDate': None,
#   'dividendYield': 0.009805092718934927,
#   'nextEarningsDate': '2020-05-18',
#   'exDividendDate': '2020-02-11',
#   'peRatio': 26,
#   'beta': 1.504328007760156,
#   'totalCash': 105183640812,
# ...

# %%
pr['quote'].keys()
# Out:
# dict_keys(['symbol', 'companyName', 'primaryExchange', 'calculationPrice', 'open', 'openTime', 'close', 'closeTime', 'high', 'low', 'latestPrice', 'latestSource', 'latestTime', 'latestUpdate', 'latestVolume', 'iexRealtimePrice', 'iexRealtimeSize', 'iexLastUpdated', 'delayedPrice', 'delayedPriceTime', 'oddLotDelayedPrice', 'oddLotDelayedPriceTime', 'extendedPrice', 'extendedChange', 'extendedChangePercent', 'extendedPriceTime', 'previousClose', 'previousVolume', 'change', 'changePercent', 'volume', 'iexMarketPercent', 'iexVolume', 'avgTotalVolume', 'iexBidPrice', 'iexBidSize', 'iexAskPrice', 'iexAskSize', 'marketCap', 'peRatio', 'week52High', 'week52Low', 'ytdChange', 'lastTradeTime', 'isUSMarketOpen'])

# %%
pr['company'].keys()
# Out:
# dict_keys(['symbol', 'companyName', 'exchange', 'industry', 'website', 'description', 'CEO', 'securityName', 'issueType', 'sector', 'primarySicCode', 'employees', 'tags', 'address', 'address2', 'state', 'city', 'zip', 'country', 'phone'])

# %%
pr['chart'][0]
# Out:
# {'date': '2019-02-15',
#  'open': 176.33,
#  'close': 170.79,
#  'high': 176.7,
#  'low': 177.84,
#  'volume': 25025015,
#  'uOpen': 175.66,
#  'uClose': 173.41,
#  'uHigh': 174.7,
#  'uLow': 174.11,
#  'uVolume': 25043801,
#  'change': 0,
#  'changePercent': 0,
#  'label': 'Feb 15, 19',
#  'changeOverTime': 0}

# %%
pr['balance-sheet']['balancesheet'][0].keys()
# Out:
# dict_keys(['reportDate', 'currentCash', 'shortTermInvestments', 'receivables', 'inventory', 'otherCurrentAssets', 'currentAssets', 'longTermInvestments', 'propertyPlantEquipment', 'goodwill', 'intangibleAssets', 'otherAssets', 'totalAssets', 'accountsPayable', 'currentLongTermDebt', 'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt', 'otherLiabilities', 'minorityInterest', 'totalLiabilities', 'commonStock', 'retainedEarnings', 'treasuryStock', 'capitalSurplus', 'shareholderEquity', 'netTangibleAssets'])

# %%
pr['cash-flow']['cashflow'][0].keys()
# Out:
# dict_keys(['reportDate', 'netIncome', 'depreciation', 'changesInReceivables', 'changesInInventories', 'cashChange', 'cashFlow', 'capitalExpenditures', 'investments', 'investingActivityOther', 'totalInvestingCashFlows', 'dividendsPaid', 'netBorrowings', 'otherFinancingCashFlows', 'cashFlowFinancing', 'exchangeRateEffect'])

# %%
pr['dividends']
# Out:
# [{'exDate': '2020-02-09',
#   'paymentDate': '2020-02-24',
#   'recordDate': '2020-02-13',
#   'declaredDate': '2020-02-11',
#   'amount': '0.79',
#   'flag': 'hCsa',
#   'currency': 'USD',
#   'description': 'rSaydrsi arOehn',
#   'frequency': 'rtyquarle',
#   'date': '2020-02-18'},
#  {'exDate': '2019-11-12',
#   'paymentDate': '2019-11-25',
#   'recordDate': '2019-11-19',
#   'declaredDate': '2019-11-09',
#   'amount': '0.8',
#   'flag': 'haCs',
#   'currency': 'USD',
#   'description': 'Srradrineay sOh',
#   'frequency': 'luqetyarr',
#   'date': '2020-02-18'},
#  {'exDate': '2019-08-21',
#   'paymentDate': '2019-08-20',
#   'recordDate': '2019-08-13',
#   'declaredDate': '2019-08-07',
#   'amount': '0.81',
#   'flag': 'saCh',
#   'currency': 'USD',
#   'description': 'ayrnae rdrOsShi',
#   'frequency': 'yrualetrq',
#   'date': '2020-02-18'},
#  {'exDate': '2019-05-17',
#   'paymentDate': '2019-05-20',
#   'recordDate': '2019-05-18',
#   'declaredDate': '2019-05-12',
# ...

# %%
pr['earnings']['earnings'][0]
# Out:
# {'actualEPS': 5.17,
#  'consensusEPS': 4.72,
#  'announceTime': 'CMA',
#  'numberOfEstimates': 38,
#  'EPSSurpriseDollar': 0.47,
#  'EPSReportDate': '2020-01-31',
#  'fiscalPeriod': 'Q4 2019',
#  'fiscalEndDate': '2020-01-10',
#  'yearAgo': 4.19,
#  'yearAgoChangePercent': 0.2032,
#  'currency': 'USD'}

# %%
pr['financials']
# Out:
# {'symbol': 'AAPL',
#  'financials': [{'reportDate': '2020-01-10',
#    'grossProfit': 35209933981,
#    'costOfRevenue': 57440974974,
#    'operatingRevenue': 95106964908,
#    'totalRevenue': 91846021003,
#    'operatingIncome': 25698611317,
#    'netIncome': 22238467928,
#    'researchAndDevelopment': 4492748168,
#    'operatingExpense': 66735506860,
#    'currentAssets': 163321488415,
#    'totalAssets': 342993905889,
#    'totalLiabilities': 256367336796,
#    'currentCash': 23569330884,
#    'currentDebt': 16897858067,
#    'shortTermDebt': 16473241246,
#    'longTermDebt': 101122573700,
#    'totalCash': 110827215310,
#    'totalDebt': 117154630620,
#    'shareholderEquity': 91848684702,
#    'cashChange': -8966744321,
#    'cashFlow': 31900106539}]}

# %%
pr['advanced-stats'].keys()
# Out:
# dict_keys(['week52change', 'week52high', 'week52low', 'marketcap', 'employees', 'day200MovingAvg', 'day50MovingAvg', 'float', 'avg10Volume', 'avg30Volume', 'ttmEPS', 'ttmDividendRate', 'companyName', 'sharesOutstanding', 'maxChangePercent', 'year5ChangePercent', 'year2ChangePercent', 'year1ChangePercent', 'ytdChangePercent', 'month6ChangePercent', 'month3ChangePercent', 'month1ChangePercent', 'day30ChangePercent', 'day5ChangePercent', 'nextDividendDate', 'dividendYield', 'nextEarningsDate', 'exDividendDate', 'peRatio', 'beta', 'totalCash', 'currentDebt', 'revenue', 'grossProfit', 'totalRevenue', 'EBITDA', 'revenuePerShare', 'revenuePerEmployee', 'debtToEquity', 'profitMargin', 'enterpriseValue', 'enterpriseValueToRevenue', 'priceToSales', 'priceToBook', 'forwardPERatio', 'pegRatio', 'peHigh', 'peLow', 'week52highDate', 'week52lowDate', 'putCallRatio'])

# %%
r = requests.get(f'https://sandbox.iexapis.com/stable/stock/{symbol}/earnings/2?period=annual&token={token}')
pr = json.loads(r.text)
pr['earnings']
# Out:
# [{'actualEPS': 12.39,
#   'consensusEPS': 11.94,
#   'announceTime': 'CAM',
#   'numberOfEstimates': 44,
#   'EPSSurpriseDollar': 0.21,
#   'EPSReportDate': '2019-11-12',
#   'fiscalPeriod': 'FY ending in 2019',
#   'fiscalEndDate': '2019-10-08',
#   'yearAgo': 11.96,
#   'yearAgoChangePercent': -0.0017,
#   'currency': None},
#  {'actualEPS': 11.97,
#   'announceTime': 'AMC',
#   'EPSReportDate': '2018-11-06',
#   'fiscalPeriod': 'FY ending in 2018',
#   'fiscalEndDate': '2018-10-10',
#   'yearAgo': 9.26,
#   'yearAgoChangePercent': 0.297}]

# %%
r = requests.get(f'https://sandbox.iexapis.com/stable/stock/{symbol}/earnings/2?period=quarter&token={token}')
pr = json.loads(r.text)
pr['earnings']
# Out:
# [{'actualEPS': 5.1,
#   'consensusEPS': 4.62,
#   'announceTime': 'CAM',
#   'numberOfEstimates': 40,
#   'EPSSurpriseDollar': 0.47,
#   'EPSReportDate': '2020-01-30',
#   'fiscalPeriod': 'Q4 2019',
#   'fiscalEndDate': '2020-01-03',
#   'yearAgo': 4.25,
#   'yearAgoChangePercent': 0.1944,
#   'currency': 'USD'},
#  {'actualEPS': 3.12,
#   'consensusEPS': 2.92,
#   'announceTime': 'MAC',
#   'numberOfEstimates': 40,
#   'EPSSurpriseDollar': 0.2,
#   'EPSReportDate': '2019-11-10',
#   'fiscalPeriod': 'Q3 2019',
#   'fiscalEndDate': '2019-10-04',
#   'yearAgo': 3.02,
#   'yearAgoChangePercent': 0.0413,
#   'currency': 'USD'}]

# %%
r = requests.get(f'https://sandbox.iexapis.com/stable/stock/{symbol}/earnings/4?token={token}')
pr = json.loads(r.text)
pr
# Out:
# {'symbol': 'AAPL',
#  'earnings': [{'actualEPS': 5.23,
#    'consensusEPS': 4.69,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 39,
#    'EPSSurpriseDollar': 0.46,
#    'EPSReportDate': '2020-02-11',
#    'fiscalPeriod': 'Q4 2019',
#    'fiscalEndDate': '2020-01-12',
#    'yearAgo': 4.39,
#    'yearAgoChangePercent': 0.1983,
#    'currency': 'USD'},
#   {'actualEPS': 3.1,
#    'consensusEPS': 2.86,
#    'announceTime': 'MCA',
#    'numberOfEstimates': 40,
#    'EPSSurpriseDollar': 0.2,
#    'EPSReportDate': '2019-11-09',
#    'fiscalPeriod': 'Q3 2019',
#    'fiscalEndDate': '2019-10-02',
#    'yearAgo': 2.99,
#    'yearAgoChangePercent': 0.0428,
#    'currency': 'USD'},
#   {'actualEPS': 2.24,
#    'consensusEPS': 2.12,
#    'announceTime': 'MCA',
#    'numberOfEstimates': 38,
#    'EPSSurpriseDollar': 0.09,
#    'EPSReportDate': '2019-07-30',
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-07-02',
#    'yearAgo': 2.41,
#    'yearAgoChangePercent': -0.0717,
# ...

# %%
r = requests.get(f'https://sandbox.iexapis.com/stable/stock/{symbol}/batch?types=earnings,income&last=2&period=annual&token={token}')
annual_income_earnings = json.loads(r.content)

# %%
annual_income_earnings['earnings']['earnings'][0]
# Out:
# {'actualEPS': 12.38,
#  'consensusEPS': 12.07,
#  'announceTime': 'CAM',
#  'numberOfEstimates': 42,
#  'EPSSurpriseDollar': 0.21,
#  'EPSReportDate': '2019-11-03',
#  'fiscalPeriod': 'FY ending in 2019',
#  'fiscalEndDate': '2019-10-13',
#  'yearAgo': 12.22,
#  'yearAgoChangePercent': -0.0018,
#  'currency': None}

# %%
r = requests.get(f'https://sandbox.iexapis.com/stable/stock/{symbol}/advanced-stats?token={token}')
company_stats = json.loads(r.content)

# %%
company_stats
# Out:
# {'week52change': 0.94447,
#  'week52high': 341.66,
#  'week52low': 174.44,
#  'marketcap': 1469009655128,
#  'employees': 138543,
#  'day200MovingAvg': 237.78,
#  'day50MovingAvg': 301.1,
#  'float': 4564208038,
#  'avg10Volume': 33820297.1,
#  'avg30Volume': 34220075.4,
#  'ttmEPS': 13.1372,
#  'ttmDividendRate': 3.05,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 4553019227,
#  'maxChangePercent': 335.0886,
#  'year5ChangePercent': 1.76,
#  'year2ChangePercent': 1.0764,
#  'year1ChangePercent': 0.95668,
#  'ytdChangePercent': 0.090835,
#  'month6ChangePercent': 0.583255,
#  'month3ChangePercent': 0.237455,
#  'month1ChangePercent': 0.033225,
#  'day30ChangePercent': 0.114387,
#  'day5ChangePercent': 0.006182,
#  'nextDividendDate': None,
#  'dividendYield': 0.009303688924132915,
#  'nextEarningsDate': '2020-05-20',
#  'exDividendDate': '2020-02-13',
#  'peRatio': 26.49,
#  'beta': 1.5114887772176488,
#  'totalCash': 105481939372,
#  'currentDebt': 16848067984,
# ...

# %%
r = requests.get(f'https://sandbox.iexapis.com/stable/stock/{symbol}/batch?types=balance-sheet,financials,company,chart&range=1y&token={token}')
pr = json.loads(r.content)

# %%
pr['financials']['financials'][0]
# Out:
# {'reportDate': '2020-01-12',
#  'grossProfit': 36488028955,
#  'costOfRevenue': 59331822184,
#  'operatingRevenue': 94909099482,
#  'totalRevenue': 92086633988,
#  'operatingIncome': 25308017802,
#  'netIncome': 22434554539,
#  'researchAndDevelopment': 4496647697,
#  'operatingExpense': 68354891708,
#  'currentAssets': 163812479210,
#  'totalAssets': 344195267696,
#  'totalLiabilities': 252545530768,
#  'currentCash': 23141200873,
#  'currentDebt': 16828578867,
#  'shortTermDebt': 16716774580,
#  'longTermDebt': 101891068032,
#  'totalCash': 111397638883,
#  'totalDebt': 120513221187,
#  'shareholderEquity': 93404309770,
#  'cashChange': -8970748881,
#  'cashFlow': 30770758772}

# %%
r = requests.get(f'https://cloud.iexapis.com/stable/stock/{symbol}/batch?types=earnings,income&period=annual&token={api_token}')
annual_income_earnings = json.loads(r.content)

# %%
annual_income_earnings['earnings']
# Out:
# {'symbol': 'AAPL',
#  'earnings': [{'actualEPS': 11.89,
#    'consensusEPS': 11.68,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 42,
#    'EPSSurpriseDollar': 0.21,
#    'EPSReportDate': '2019-10-30',
#    'fiscalPeriod': 'FY ending in 2019',
#    'fiscalEndDate': '2019-09-30',
#    'yearAgo': 11.91,
#    'yearAgoChangePercent': -0.0017,
#    'currency': None}]}

# %%
r = requests.get(f'https://cloud.iexapis.com/stable/stock/{symbol}/batch?types=earnings,income&last=8&period=quarter&token={api_token}')
quarter_income_earnings = json.loads(r.content)

# %%
quarter_income_earnings['earnings']['earnings']
# Out:
# [{'actualEPS': 4.99,
#   'consensusEPS': 4.54,
#   'announceTime': 'AMC',
#   'numberOfEstimates': 38,
#   'EPSSurpriseDollar': 0.45,
#   'EPSReportDate': '2020-01-28',
#   'fiscalPeriod': 'Q4 2019',
#   'fiscalEndDate': '2019-12-31',
#   'yearAgo': 4.18,
#   'yearAgoChangePercent': 0.1938,
#   'currency': 'USD'},
#  {'actualEPS': 3.03,
#   'consensusEPS': 2.83,
#   'announceTime': 'AMC',
#   'numberOfEstimates': 39,
#   'EPSSurpriseDollar': 0.2,
#   'EPSReportDate': '2019-10-30',
#   'fiscalPeriod': 'Q3 2019',
#   'fiscalEndDate': '2019-09-30',
#   'yearAgo': 2.91,
#   'yearAgoChangePercent': 0.0412,
#   'currency': 'USD'},
#  {'actualEPS': 2.18,
#   'consensusEPS': 2.09,
#   'announceTime': 'AMC',
#   'numberOfEstimates': 37,
#   'EPSSurpriseDollar': 0.09,
#   'EPSReportDate': '2019-07-30',
#   'fiscalPeriod': 'Q2 2019',
#   'fiscalEndDate': '2019-06-30',
#   'yearAgo': 2.34,
#   'yearAgoChangePercent': -0.0684,
#   'currency': 'USD'},
#  {'actualEPS': 2.46,
# ...

# %%
annual_income_earnings['income']
# Out:
# {'symbol': 'AAPL',
#  'income': [{'reportDate': '2019-09-30',
#    'totalRevenue': 259968000000,
#    'costOfRevenue': 162264000000,
#    'grossProfit': 97704000000,
#    'researchAndDevelopment': 16217000000,
#    'sellingGeneralAndAdmin': 18245000000,
#    'operatingExpense': 196726000000,
#    'operatingIncome': 63242000000,
#    'otherIncomeExpenseNet': 2495000000,
#    'ebit': 63242000000,
#    'interestIncome': 3576000000,
#    'pretaxIncome': 65737000000,
#    'incomeTax': 10481000000,
#    'minorityInterest': 0,
#    'netIncome': 55256000000,
#    'netIncomeBasic': 55256000000}]}

# %%
((quarter_income_earnings['income']['income'][0]['totalRevenue'] + quarter_income_earnings['income']['income'][1]['totalRevenue'] + quarter_income_earnings['income']['income'][2]['totalRevenue'] + quarter_income_earnings['income']['income'][3]['totalRevenue'])-(quarter_income_earnings['income']['income'][4]['totalRevenue'] + quarter_income_earnings['income']['income'][5]['totalRevenue'] + quarter_income_earnings['income']['income'][6]['totalRevenue'] + quarter_income_earnings['income']['income'][7]['totalRevenue']))/(quarter_income_earnings['income']['income'][4]['totalRevenue'] + quarter_income_earnings['income']['income'][5]['totalRevenue'] + quarter_income_earnings['income']['income'][6]['totalRevenue'] + quarter_income_earnings['income']['income'][7]['totalRevenue'])
# Out:
# 0.021443992281385528

# %%
((quarter_income_earnings['earnings']['earnings'][0]['actualEPS']+quarter_income_earnings['earnings']['earnings'][1]['actualEPS']+quarter_income_earnings['earnings']['earnings'][2]['actualEPS']+quarter_income_earnings['earnings']['earnings'][3]['actualEPS'])-(quarter_income_earnings['earnings']['earnings'][0]['yearAgo']+quarter_income_earnings['earnings']['earnings'][1]['yearAgo']+quarter_income_earnings['earnings']['earnings'][2]['yearAgo']+quarter_income_earnings['earnings']['earnings'][3]['yearAgo']))/(quarter_income_earnings['earnings']['earnings'][0]['yearAgo']+quarter_income_earnings['earnings']['earnings'][1]['yearAgo']+quarter_income_earnings['earnings']['earnings'][2]['yearAgo']+quarter_income_earnings['earnings']['earnings'][3]['yearAgo'])
# Out:
# 0.04111842105263158

# %%
quarter_income_earnings['income']['income'][0]['totalRevenue'] + quarter_income_earnings['income']['income'][1]['totalRevenue'] + quarter_income_earnings['income']['income'][2]['totalRevenue'] + quarter_income_earnings['income']['income'][3]['totalRevenue']
# Out:
# 267317000000

# %%
quarter_income_earnings['income']['income'][0]
# Out:
# {'reportDate': '2019-12-31',
#  'totalRevenue': 91722000000,
#  'costOfRevenue': 56773000000,
#  'grossProfit': 34949000000,
#  'researchAndDevelopment': 4451000000,
#  'sellingGeneralAndAdmin': 5197000000,
#  'operatingExpense': 66421000000,
#  'operatingIncome': 25301000000,
#  'otherIncomeExpenseNet': 617000000,
#  'ebit': 25301000000,
#  'interestIncome': 785000000,
#  'pretaxIncome': 25918000000,
#  'incomeTax': 3682000000,
#  'minorityInterest': 0,
#  'netIncome': 22236000000,
#  'netIncomeBasic': 22236000000}

# %%
quarter_income_earnings['earnings']['earnings']
# Out:
# [{'actualEPS': 4.99,
#   'consensusEPS': 4.54,
#   'announceTime': 'AMC',
#   'numberOfEstimates': 38,
#   'EPSSurpriseDollar': 0.45,
#   'EPSReportDate': '2020-01-28',
#   'fiscalPeriod': 'Q4 2019',
#   'fiscalEndDate': '2019-12-31',
#   'yearAgo': 4.18,
#   'yearAgoChangePercent': 0.1938,
#   'currency': 'USD'},
#  {'actualEPS': 3.03,
#   'consensusEPS': 2.83,
#   'announceTime': 'AMC',
#   'numberOfEstimates': 39,
#   'EPSSurpriseDollar': 0.2,
#   'EPSReportDate': '2019-10-30',
#   'fiscalPeriod': 'Q3 2019',
#   'fiscalEndDate': '2019-09-30',
#   'yearAgo': 2.91,
#   'yearAgoChangePercent': 0.0412,
#   'currency': 'USD'},
#  {'actualEPS': 2.18,
#   'consensusEPS': 2.09,
#   'announceTime': 'AMC',
#   'numberOfEstimates': 37,
#   'EPSSurpriseDollar': 0.09,
#   'EPSReportDate': '2019-07-30',
#   'fiscalPeriod': 'Q2 2019',
#   'fiscalEndDate': '2019-06-30',
#   'yearAgo': 2.34,
#   'yearAgoChangePercent': -0.0684,
#   'currency': 'USD'},
#  {'actualEPS': 2.46,
# ...

# %%
r = requests.get(f'https://cloud.iexapis.com/stable/stock/{symbol}/advanced-stats?token={api_token}')
pr = json.loads(r.content)

# %%
pr
# Out:
# {'week52change': 0.92267,
#  'week52high': 327.85,
#  'week52low': 169.38,
#  'marketcap': 1431657056000,
#  'employees': 137000,
#  'day200MovingAvg': 236.17,
#  'day50MovingAvg': 298.4,
#  'float': 4368579868,
#  'avg10Volume': 32406812.2,
#  'avg30Volume': 33424856.7,
#  'ttmEPS': 12.7549,
#  'ttmDividendRate': 3.04,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 4375480000,
#  'maxChangePercent': 322.9604,
#  'year5ChangePercent': 1.733,
#  'year2ChangePercent': 1.0509,
#  'year1ChangePercent': 0.92267,
#  'ytdChangePercent': 0.089396,
#  'month6ChangePercent': 0.565775,
#  'month3ChangePercent': 0.237191,
#  'month1ChangePercent': 0.032307,
#  'day30ChangePercent': 0.114252,
#  'day5ChangePercent': 0.006119,
#  'nextDividendDate': None,
#  'dividendYield': 0.009290953545232274,
#  'nextEarningsDate': '2020-05-05',
#  'exDividendDate': '2020-02-07',
#  'peRatio': 25.5,
#  'beta': 1.4588594770024648,
#  'totalCash': 100580000000,
#  'currentDebt': 16240000000,
# ...

# %%
for i in pr:
    print("symbol_dict[symbol]['"+str(i)+"']=round(float(company_stats['"+str(i)+"']),2)")
    print("symbol_dict[symbol]['"+str(i)+"']=float()")
# Out:
# symbol_dict[symbol]['week52change']=round(float(company_stats['week52change']),2)
# symbol_dict[symbol]['week52change']=float()
# symbol_dict[symbol]['week52high']=round(float(company_stats['week52high']),2)
# symbol_dict[symbol]['week52high']=float()
# symbol_dict[symbol]['week52low']=round(float(company_stats['week52low']),2)
# symbol_dict[symbol]['week52low']=float()
# symbol_dict[symbol]['marketcap']=round(float(company_stats['marketcap']),2)
# symbol_dict[symbol]['marketcap']=float()
# symbol_dict[symbol]['employees']=round(float(company_stats['employees']),2)
# symbol_dict[symbol]['employees']=float()
# symbol_dict[symbol]['day200MovingAvg']=round(float(company_stats['day200MovingAvg']),2)
# symbol_dict[symbol]['day200MovingAvg']=float()
# symbol_dict[symbol]['day50MovingAvg']=round(float(company_stats['day50MovingAvg']),2)
# symbol_dict[symbol]['day50MovingAvg']=float()
# symbol_dict[symbol]['float']=round(float(company_stats['float']),2)
# ...

# %%
(quarter_income_earnings['earnings']['earnings'][0]['actualEPS']+quarter_income_earnings['earnings']['earnings'][1]['actualEPS']+quarter_income_earnings['earnings']['earnings'][2]['actualEPS']+quarter_income_earnings['earnings']['earnings'][3]['actualEPS'])
# Out:
# 12.66

# %%
r = requests.get(f'https://cloud.iexapis.com/stable/stock/AAPL/quote?token={api_token}')
pr = json.loads(r.content)

# %%
pr['latestPrice']
# Out:
# 318.83

# %%
pr['latestVolume']
# Out:
# 37756888

# %%
pr
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'primaryExchange': 'NASDAQ',
#  'calculationPrice': 'tops',
#  'open': None,
#  'openTime': None,
#  'close': None,
#  'closeTime': None,
#  'high': None,
#  'low': None,
#  'latestPrice': 318.83,
#  'latestSource': 'IEX price',
#  'latestTime': '3:59:57 PM',
#  'latestUpdate': 1582059597963,
#  'latestVolume': 37756888,
#  'iexRealtimePrice': 318.83,
#  'iexRealtimeSize': 100,
#  'iexLastUpdated': 1582059597963,
#  'delayedPrice': None,
#  'delayedPriceTime': None,
#  'oddLotDelayedPrice': None,
#  'oddLotDelayedPriceTime': None,
#  'extendedPrice': None,
#  'extendedChange': None,
#  'extendedChangePercent': None,
#  'extendedPriceTime': None,
#  'previousClose': 324.95,
#  'previousVolume': 20028447,
#  'change': -6.12,
#  'changePercent': -0.01883,
#  'volume': 37756888,
#  'iexMarketPercent': 0.014234462331747256,
#  'iexVolume': 537449,
#  'avgTotalVolume': 32910052,
#  'iexBidPrice': 0,
#  'iexBidSize': 0,
# ...

# %%
import numpy as np
import pandas as pd
import requests
import json
import datetime
import plotly.figure_factory as FF
from chart_studio.plotly import iplot
import plotly.graph_objects as go
import matplotlib.pyplot as plt
from PIL import Image
from mpl_finance import candlestick_ohlc

api_token = 'sk_f491c9326e6a4b79a7ed5b1689c178f3'
token = 'pk_36b1f2b4c74a4c86bec74d5e48fb2517'
# Out:
# c:\users\rob\trading\venv_38\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   __warnings.warn('\n\n  ================================================================='+

# %%
r = requests.get(f'https://cloud.iexapis.com/stable/stock/spy/chart/5dm?token={api_token}')

# %%
pr = json.loads(r.content)

# %%
df = pd.DataFrame(pr)

# %%
df = df[-39:]

# %%
df.head()
# Out:
#            date minute  label     open     high      low    close     average  \
# 156  2021-03-29  09:30  09:30  394.440  395.620  394.400  395.620  394.944290
# 157  2021-03-29  09:40  09:40  395.640  395.685  394.850  394.890  395.263869
# 158  2021-03-29  09:50  09:50  394.880  395.105  394.100  394.100  394.525334
# 159  2021-03-29  10:00  10:00  394.085  394.380  393.660  393.760  394.033578
# 160  2021-03-29  10:10  10:10  393.700  394.290  393.595  393.935  393.902602
#
#      volume      notional  numberOfTrades  marketOpen  marketHigh  marketLow  \
# 156   36697  1.449327e+07             196      394.40      395.65     394.35
# 157   47164  1.864224e+07             186      395.63      395.71     394.83
# 158   20794  8.203759e+06             127      394.97      395.12     394.06
# 159   18296  7.209237e+06             156      394.12      394.39     393.59
# 160   42011  1.654824e+07             236      393.77      394.33     393.52
#
# ...

# %%
def future_max_price(row):
    i = int(row['index'])
    try:
        return max(df.iloc[i+1]['high'],df.iloc[i+2]['high'])
    except:
        return None
    
def future_min_price(row):
    i = int(row['index'])
    try:
        return min(df.iloc[i+1]['low'],df.iloc[i+2]['low'])
    except:
        return None
    
def stochastic(row):
    return ((row['close']-row['14_min'])/(row['14_max']-row['14_min']))*100


def gain(row):
    if row['change'] >= 0:
        return row['change']
    else:
        return 0

def loss(row):
    if row['change']<= 0:
        return row['change']
    else:
        return 0
    
def rsi(row):
    return 100 - (100 / (1+((row['prev_avg_gain']*13)+row['gain'])/-((row['prev_avg_loss']*13)+row['loss'])))

# %%
old_df = pd.read_csv('master_spy_data.csv',index_col='Unnamed: 0')
combined = old_df.append(df)
combined.drop(columns='index', axis=1,inplace=True)
combined.reset_index(inplace=True)
combined.drop(columns='index', axis=1,inplace=True)
combined.reset_index(inplace=True)

# %%
df = combined.copy()

# %%
df.head()
# Out:
#    index  20_max  20_min     average    close        date     high  label  \
# 0      0     NaN     NaN  394.936017  395.100  2021-03-18  395.270  09:30
# 1      1     NaN     NaN  394.938327  394.320  2021-03-18  395.390  09:40
# 2      2     NaN     NaN  394.749679  395.215  2021-03-18  395.255  09:50
# 3      3     NaN     NaN  394.766855  394.505  2021-03-18  395.090  10:00
# 4      4     NaN     NaN  394.450056  394.760  2021-03-18  394.760  10:10
#
#        low  lowerband  ...  14_min  14_max   gain  loss  avg_gain  avg_loss  \
# 0  394.470        NaN  ...     NaN     NaN  0.000  0.00       NaN       NaN
# 1  394.320        NaN  ...     NaN     NaN  0.000 -0.78       NaN       NaN
# 2  394.020        NaN  ...     NaN     NaN  0.895  0.00       NaN       NaN
# 3  394.265        NaN  ...     NaN     NaN  0.000 -0.71       NaN       NaN
# 4  394.190        NaN  ...     NaN     NaN  0.255  0.00       NaN       NaN
#
#    prev_avg_gain  prev_avg_loss  stochastic  rsi
# ...

# %%
df.tail()
# Out:
#      index  20_max  20_min     average    close        date     high  label  \
# 306    306     NaN     NaN  396.161723  396.205  2021-03-29  396.385  15:10
# 307    307     NaN     NaN  396.520358  396.600  2021-03-29  396.740  15:20
# 308    308     NaN     NaN  396.519242  396.580  2021-03-29  396.665  15:30
# 309    309     NaN     NaN  396.100976  395.830  2021-03-29  396.585  15:40
# 310    310     NaN     NaN  395.606465  395.740  2021-03-29  396.075  15:50
#
#         low  lowerband  ...  14_min  14_max  gain  loss  avg_gain  avg_loss  \
# 306  395.92        NaN  ...     NaN     NaN   NaN   NaN       NaN       NaN
# 307  396.07        NaN  ...     NaN     NaN   NaN   NaN       NaN       NaN
# 308  396.23        NaN  ...     NaN     NaN   NaN   NaN       NaN       NaN
# 309  395.69        NaN  ...     NaN     NaN   NaN   NaN       NaN       NaN
# 310  395.14        NaN  ...     NaN     NaN   NaN   NaN       NaN       NaN
#
#      prev_avg_gain  prev_avg_loss  stochastic  rsi
# ...

# %%
df['change'] = df['close'] - df['close'].shift(1)
df['gain'] = df.apply(gain, axis = 1)
df['loss'] = df.apply(loss, axis = 1)
df['avg_gain'] = df['gain'].rolling(14).mean()
df['avg_loss'] = df['loss']. rolling(14).mean()
df['prev_avg_gain'] = df['avg_gain'].shift(1)
df['prev_avg_loss'] = df['avg_loss'].shift(1)
df['ma_20'] = df['close'].rolling(20).mean()
df['ma_9'] = df['close'].rolling(9).mean()
df['ma_50'] = df['close'].rolling(50).mean()
df['14_min'] = df['close'].rolling(14).min()
df['14_max'] = df['close'].rolling(14).max()
df['stdev'] = abs(df['close'].rolling(20).std())
df['upperband'] = df['ma_20'] + (df['stdev']*2)
df['lowerband'] = df['ma_20'] - (df['stdev']*2)
df['future_max_30'] = df.apply(future_max_price,axis=1)
df['future_min_30'] = df.apply(future_min_price,axis=1)
df['max_change'] = df['future_max_30'] - df['close']
df['min_change'] = df['future_min_30'] - df['close']
df['stochastic'] = df.apply(stochastic, axis = 1)
df['rsi'] = df.apply(rsi, axis = 1)

# %%
df[df['max_change']>1]
# Out:
#      index   20_max   20_min     average    close        date     high  label  \
# 3        3      NaN      NaN  394.766855  394.505  2021-03-18  395.090  10:00
# 20      20  396.690  394.020  394.860349  394.620  2021-03-18  395.400  12:50
# 40      40  396.105  387.410  388.048460  387.530  2021-03-19  388.990  09:40
# 42      42  396.105  387.155  387.673300  387.715  2021-03-19  388.520  10:00
# 44      44  396.105  387.155  388.913922  388.825  2021-03-19  389.120  10:20
# 45      45  396.105  387.155  388.364159  388.690  2021-03-19  388.945  10:30
# 49      49  394.230  387.155  389.455065  389.305  2021-03-19  389.680  11:10
# 50      50  393.645  387.155  388.962385  388.950  2021-03-19  389.400  11:20
# 51      51  393.645  387.155  389.518294  389.825  2021-03-19  389.840  11:30
# 77      77  391.550  389.420  390.224511  389.480  2021-03-19  391.160  15:50
# 123    123  394.060  391.460  391.883575  391.560  2021-03-23  392.745  10:30
# ...

# %%
for i in df.index[60:230]:
    end = i
    if df.iloc[i]['max_change'] > .99:
        target = '10_candle_dollar/10_candle_dollar_gain'
    elif df.iloc[i]['min_change']<-.99:
        target = '10_candle_dollar/10_candle_dollar_loss'
    else:
        target = '10_candle_dollar/10_candle_dollar_none'
    ohlc = df.loc[end-10:end, ['index','open', 'high', 'low', 'close']]
    upper_band = df.loc[end-10:end,'upperband']
    lower_band = df.loc[end-10:end,'lowerband']
    ma_20 = df.loc[end-10:end, 'ma_20']
    ma_9 = df.loc[end-10:end, 'ma_9']
    ma_50 = df.loc[end-10:end, 'ma_50']
    fig, ax = plt.subplots()
    candlestick_ohlc(ax, ohlc.values, width=0.6, colorup='green', colordown='red', alpha=0.8)
    ax.plot(ohlc.index, upper_band, color='green', linewidth = 4)
    ax.plot(ohlc.index, lower_band, color='red', linewidth = 4)
    ax.plot(ohlc.index, ma_20, color = 'blue', linewidth=5)
#     ax.plot(ohlc.index, ma_9, color = 'orange')
#     ax.plot(ohlc.index, ma_50, color = 'purple')
    ax.axis('off')
    fig.savefig(f'{target}/{end}_mpl_test.jpeg')
    plt.close(fig)

# %%
for i in df.index[23:269]:
    end = i
    if df.iloc[i]['max_change'] > .50:
        target = '3_candle_50c/3_candle_50c_gain'
    elif df.iloc[i]['min_change']<-.50:
        target = '3_candle_50c/3_candle_50c_loss'
    else:
        target = '3_candle_50c/3_candle_50c_none'
    ohlc = df.loc[end-3:end, ['index','open', 'high', 'low', 'close']]
    upper_band = df.loc[end-3:end,'upperband']
    lower_band = df.loc[end-3:end,'lowerband']
    ma_20 = df.loc[end-3:end, 'ma_20']
    ma_9 = df.loc[end-3:end, 'ma_9']
    ma_50 = df.loc[end-3:end, 'ma_50']
    fig, ax = plt.subplots()
    candlestick_ohlc(ax, ohlc.values, width=0.6, colorup='green', colordown='red', alpha=0.8)
    ax.plot(ohlc.index, upper_band, color='green', linewidth = 4)
    ax.plot(ohlc.index, lower_band, color='red', linewidth = 4)
    ax.plot(ohlc.index, ma_20, color = 'blue', linewidth=5)
#     ax.plot(ohlc.index, ma_9, color = 'orange')
#     ax.plot(ohlc.index, ma_50, color = 'purple')
    ax.axis('off')
    fig.savefig(f'{target}/{end}_mpl_test.jpeg')
    plt.close(fig)

# %%
for i in df.index[55:269]:
    end = i
    if df.iloc[i]['max_change'] > .50:
        target = '5_candle_50c_gain'
    else:
        target = '5_candle_50c_no_gain'
    ohlc = df.loc[end-5:end, ['index','open', 'high', 'low', 'close']]
    upper_band = df.loc[end-5:end,'upperband']
    lower_band = df.loc[end-5:end,'lowerband']
    ma_20 = df.loc[end-5:end, 'ma_20']
    ma_9 = df.loc[end-5:end, 'ma_9']
    ma_50 = df.loc[end-5:end, 'ma_50']
    fig, ax = plt.subplots()
    candlestick_ohlc(ax, ohlc.values, width=0.6, colorup='green', colordown='red', alpha=0.8)
    # ax.plot(ohlc.index, upper_band, color='green')
    # ax.plot(ohlc.index, lower_band, color='red')
    ax.plot(ohlc.index, ma_20, color = 'blue')
    ax.plot(ohlc.index, ma_9, color = 'orange')
    ax.plot(ohlc.index, ma_50, color = 'purple')
    ax.axis('off')
    fig.savefig(f'{target}/{end}_mpl_test.jpeg')
    plt.close(fig)

# %%
for i in df.index[23:308]:
    end = i
    fig, ax = plt.subplots()
    ax.plot(df.loc[end-20:end]['index'], df.loc[end-20:end]['rsi'], color = 'black', linewidth = 4)
    ax.plot(df.loc[end-20:end]['index'], df.loc[end-20:end]['stochastic'], color = 'green', linewidth = 4)
#     ax.axhline(y=70, color = 'black', linewidth = 4)
#     ax.axhline(y=30, color = 'black', linewidth = 4)
        
    if df.iloc[end]['max_change'] > .40 and df.iloc[end]['min_change'] >-20 and df.iloc[end]['rsi'] > 70:
        target = 'rsi_20_40c/rsi_20_gain'
    elif df.iloc[end]['min_change']<-.40 and df.iloc[end]['max_change'] <.20 and df.iloc[end]['rsi'] > 70:
        target = 'rsi_20_40c/rsi_20_loss'
    else:
        plt.close(fig)
        continue
    ax.axis('off')
    fig.savefig(f'{target}/{end}_rsi_20.jpeg')
    plt.close(fig)

# %%
import os
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  'rsi_20_40c/',
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  'rsi_20_40c/',
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

AUTOTUNE = tf.data.AUTOTUNE

class_names = train_ds.class_names
print(class_names)

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
# Out:
# Found 49 files belonging to 2 classes.
# Using 40 files for training.
# Found 49 files belonging to 2 classes.
# Using 9 files for validation.
# ['rsi_20_gain', 'rsi_20_loss']

# %%
num_classes = 2

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(124, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# rescaling_50 (Rescaling)     (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_70 (MaxPooling (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 22, 22, 64)        0
# ...

# %%
epochs=15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 2/2 [==============================] - 4s 2s/step - loss: 1.8902 - accuracy: 0.5667 - val_loss: 0.6966 - val_accuracy: 0.3333
# Epoch 2/15
# 2/2 [==============================] - 1s 449ms/step - loss: 0.7002 - accuracy: 0.5271 - val_loss: 0.6891 - val_accuracy: 0.5556
# Epoch 3/15
# 2/2 [==============================] - 1s 446ms/step - loss: 0.6999 - accuracy: 0.4729 - val_loss: 0.8057 - val_accuracy: 0.4444
# Epoch 4/15
# 2/2 [==============================] - 1s 461ms/step - loss: 0.6623 - accuracy: 0.6083 - val_loss: 0.7290 - val_accuracy: 0.4444
# Epoch 5/15
# 2/2 [==============================] - 1s 450ms/step - loss: 0.6472 - accuracy: 0.6083 - val_loss: 0.7014 - val_accuracy: 0.3333
# Epoch 6/15
# 2/2 [==============================] - 1s 440ms/step - loss: 0.6542 - accuracy: 0.8479 - val_loss: 0.7122 - val_accuracy: 0.5556
# Epoch 7/15
# ...

# %%
for i in os.listdir('rsi_20_40c/rsi_20_gain/'):
    


    img = keras.preprocessing.image.load_img(
        f"rsi_20_40c/rsi_20_gain/{i}", target_size=(img_height, img_width)
    )
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print(i,
        "This image most likely belongs to {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )
# Out:
# 107_rsi_20.jpeg This image most likely belongs to rsi_20_loss with a 56.76 percent confidence.
# 164_rsi_20.jpeg This image most likely belongs to rsi_20_gain with a 63.71 percent confidence.
# 216_rsi_20.jpeg This image most likely belongs to rsi_20_loss with a 58.12 percent confidence.
# 219_rsi_20.jpeg This image most likely belongs to rsi_20_gain with a 50.44 percent confidence.
# 230_rsi_20.jpeg This image most likely belongs to rsi_20_gain with a 65.79 percent confidence.
# 231_rsi_20.jpeg This image most likely belongs to rsi_20_gain with a 57.43 percent confidence.
# 232_rsi_20.jpeg This image most likely belongs to rsi_20_gain with a 50.63 percent confidence.
# 235_rsi_20.jpeg This image most likely belongs to rsi_20_gain with a 71.59 percent confidence.
# 237_rsi_20.jpeg This image most likely belongs to rsi_20_gain with a 74.11 percent confidence.
# 250_rsi_20.jpeg This image most likely belongs to rsi_20_loss with a 58.12 percent confidence.
# ...

# %%
model.save('below_50_model')
# Out:
# INFO:tensorflow:Assets written to: below_50_model\assets

# %%
stoch_above_50 = tf.keras.models.load_model('above_50_model/')

# %%
stoch_below_50 = tf.keras.models.load_model('below_50_model/')

# %%
df.to_csv('master_spy_data.csv')

# %%
df
# Out:
#      index   20_max   20_min     average    close        date     high  label  \
# 0        0      NaN      NaN  394.936017  395.100  2021-03-18  395.270  09:30
# 1        1      NaN      NaN  394.938327  394.320  2021-03-18  395.390  09:40
# 2        2      NaN      NaN  394.749679  395.215  2021-03-18  395.255  09:50
# 3        3      NaN      NaN  394.766855  394.505  2021-03-18  395.090  10:00
# 4        4      NaN      NaN  394.450056  394.760  2021-03-18  394.760  10:10
# 5        5      NaN      NaN  395.040867  395.090  2021-03-18  395.280  10:20
# 6        6      NaN      NaN  395.009509  395.385  2021-03-18  395.540  10:30
# 7        7      NaN      NaN  395.180803  394.990  2021-03-18  395.520  10:40
# 8        8      NaN      NaN  395.117935  395.215  2021-03-18  395.330  10:50
# 9        9      NaN      NaN  395.530268  395.795  2021-03-18  395.810  11:00
# 10      10      NaN      NaN  395.658868  395.595  2021-03-18  395.825  11:10
# ...

# %%
def future_max_price(row):
    i = int(row['index'])
    try:
        return max(df.iloc[i+1]['high'],df.iloc[i+2]['high'],df.iloc[i+3]['high'],df.iloc[i+4]['high'],df.iloc[i+5]['high'],df.iloc[i+6]['high'],df.iloc[i+7]['high'],df.iloc[i+8]['high'],df.iloc[i+9]['high'],df.iloc[i+10]['high'])
    except:
        return None
    
def future_min_price(row):
    i = int(row['index'])
    try:
        return min(df.iloc[i+1]['low'],df.iloc[i+2]['low'],df.iloc[i+3]['low'],df.iloc[i+4]['low'],df.iloc[i+5]['low'],df.iloc[i+6]['low'],df.iloc[i+7]['low'],df.iloc[i+8]['low'],df.iloc[i+9]['low'],df.iloc[i+10]['low'])
    except:
        return None
    
def stochastic(row):
    return ((row['close']-row['14_min'])/(row['14_max']-row['14_min']))*100


def gain(row):
    if row['change'] >= 0:
        return row['change']
    else:
        return 0

def loss(row):
    if row['change']<= 0:
        return row['change']
    else:
        return 0
    
def rsi(row):
    return 100 - (100 / (1+((row['prev_avg_gain']*13)+row['gain'])/-((row['prev_avg_loss']*13)+row['loss'])))

# %%
from bs4 import BeautifulSoup as bs

# %%
stock_dict = {}

stocks = ['AAPL','BAC','MSFT','FB','CSCO','ROKU','SPY','QQQ','IWM', 'INTC']
for stock in stocks:
    r = requests.get(f"https://finance.yahoo.com/quote/{stock}/history?period1=1459296000&period2=1617062400&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true")
    soup = bs(r.content)
    scripts = soup.find_all('script')
    pr = str(scripts[52]).split('root.App.main = ')[1]
    pr = pr.split(';\n}(this));\n</script>')[0]
    fin_data = json.loads(pr)
    new_df = pd.DataFrame(fin_data['context']['dispatcher']['stores']['HistoricalPriceStore']['prices'])
    if 'type' in new_df.columns:
        new_df = new_df[new_df['type']!='DIVIDEND']
    new_df.sort_values('date', inplace=True)
    new_df.reset_index(inplace=True)
    new_df.drop('index',axis=1,inplace=True)
    stock_dict[stock] = new_df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-cae7e7789017> in <module>
#       6     soup = bs(r.content)
#       7     scripts = soup.find_all('script')
# ----> 8     pr = str(scripts[52]).split('root.App.main = ')[1]
#       9     pr = pr.split(';\n}(this));\n</script>')[0]
#      10     fin_data = json.loads(pr)
#
# IndexError: list index out of range

# %%
for stock in stock_dict:
    df = stock_dict[stock]
    df.reset_index(inplace=True)
    df['change'] = df['close'] - df['close'].shift(1)
    df['ema_26'] = df['close'].ewm(span=26).mean()
    df['ema_12'] = df['close'].ewm(span=12).mean()
    df['macd'] = df['ema_12'] - df['ema_26']
    df['signal'] = df['macd'].ewm(span=9).mean()
    df['gain'] = df.apply(gain, axis = 1)
    df['loss'] = df.apply(loss, axis = 1)
    df['avg_gain'] = df['gain'].rolling(14).mean()
    df['avg_loss'] = df['loss']. rolling(14).mean()
    df['prev_avg_gain'] = df['avg_gain'].shift(1)
    df['prev_avg_loss'] = df['avg_loss'].shift(1)
    df['ma_20'] = df['close'].rolling(20).mean()
    df['ma_9'] = df['close'].rolling(9).mean()
    df['ma_50'] = df['close'].rolling(50).mean()
    df['14_min'] = df['close'].rolling(14).min()
    df['14_max'] = df['close'].rolling(14).max()
    df['stdev'] = abs(df['close'].rolling(20).std())
    df['upperband'] = df['ma_20'] + (df['stdev']*2)
    df['lowerband'] = df['ma_20'] - (df['stdev']*2)
    df['future_max_30'] = df.apply(future_max_price,axis=1)
    df['future_min_30'] = df.apply(future_min_price,axis=1)
    df['max_change'] = df['future_max_30'] - df['close']
    df['min_change'] = df['future_min_30'] - df['close']
    df['stochastic'] = df.apply(stochastic, axis = 1)
    df['rsi'] = df.apply(rsi, axis = 1)
    
    for i in df.index[26:-10]:
        end = i
        fig, ax = plt.subplots()
        ax.plot(df.loc[end-20:end]['index'], df.loc[end-20:end]['rsi'], color = 'blue', linewidth = 4)
        ax.plot(df.loc[end-20:end]['index'], df.loc[end-20:end]['stochastic'], color = 'green', linewidth = 4)
        ax.axhline(y=70, color = 'black', linewidth = 4)
        ax.axhline(y=30, color = 'black', linewidth = 4)

        if df.iloc[end]['max_change']/df.iloc[end]['close'] > .05 and df.iloc[end]['min_change']/df.iloc[end]['close'] >-.025 and df.iloc[end]['rsi'] > 60:
            target = 'rsi_20_day/rsi_gain'
        elif df.iloc[end]['min_change']/df.iloc[end]['close'] <-.05 and df.iloc[end]['max_change']/df.iloc[end]['close'] <.025 and df.iloc[end]['rsi'] > 60:
            target = 'rsi_20_day/rsi_loss'
        else:
            plt.close(fig)
            continue
        ax.axis('off')
        fig.savefig(f'{target}/{stock}_{end}_rsi.jpeg')
        plt.close(fig)

# %%
batch_size = 32
img_height = 180
img_width = 180

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  'rsi_20_day/',
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  'rsi_20_day/',
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

AUTOTUNE = tf.data.AUTOTUNE

class_names = train_ds.class_names
print(class_names)

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
# Out:
# Found 1381 files belonging to 2 classes.
# Using 1105 files for training.
# Found 1381 files belonging to 2 classes.
# Using 276 files for validation.
# ['rsi_gain', 'rsi_loss']

# %%
num_classes = 2

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(124, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# rescaling_1 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# ...

# %%
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 35/35 [==============================] - 95s 1s/step - loss: 1.8297 - accuracy: 0.5294 - val_loss: 0.6910 - val_accuracy: 0.5797
# Epoch 2/20
# 35/35 [==============================] - 32s 905ms/step - loss: 0.6903 - accuracy: 0.5482 - val_loss: 0.6789 - val_accuracy: 0.5797
# Epoch 3/20
# 35/35 [==============================] - 33s 928ms/step - loss: 0.6871 - accuracy: 0.5579 - val_loss: 0.6802 - val_accuracy: 0.5797
# Epoch 4/20
# 35/35 [==============================] - 31s 901ms/step - loss: 0.6876 - accuracy: 0.5546 - val_loss: 0.6804 - val_accuracy: 0.5797
# Epoch 5/20
# 35/35 [==============================] - 31s 888ms/step - loss: 0.6860 - accuracy: 0.5569 - val_loss: 0.6776 - val_accuracy: 0.5797
# Epoch 6/20
# 35/35 [==============================] - 31s 899ms/step - loss: 0.6813 - accuracy: 0.5588 - val_loss: 0.6762 - val_accuracy: 0.5652
# Epoch 7/20
# ...

# %%
for i in os.listdir('rsi_20_day/rsi_loss/')[0:100]:
    


    img = keras.preprocessing.image.load_img(
        f"rsi_20_day/rsi_loss/{i}", target_size=(img_height, img_width)
    )
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print(i,
        "This image most likely belongs to {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )
# Out:
# AAPL_1125_rsi.jpeg This image most likely belongs to rsi_loss with a 99.98 percent confidence.
# AAPL_1230_rsi.jpeg This image most likely belongs to rsi_loss with a 99.72 percent confidence.
# AAPL_1231_rsi.jpeg This image most likely belongs to rsi_loss with a 86.87 percent confidence.
# AAPL_1232_rsi.jpeg This image most likely belongs to rsi_loss with a 97.43 percent confidence.
# AAPL_1233_rsi.jpeg This image most likely belongs to rsi_loss with a 99.52 percent confidence.
# AAPL_1234_rsi.jpeg This image most likely belongs to rsi_loss with a 92.55 percent confidence.
# AAPL_1235_rsi.jpeg This image most likely belongs to rsi_gain with a 97.14 percent confidence.
# AAPL_1239_rsi.jpeg This image most likely belongs to rsi_loss with a 99.98 percent confidence.
# AAPL_1240_rsi.jpeg This image most likely belongs to rsi_loss with a 99.24 percent confidence.
# AAPL_150_rsi.jpeg This image most likely belongs to rsi_loss with a 99.75 percent confidence.
# ...

# %%
model.save('rsi_above_60_model')
# Out:
# INFO:tensorflow:Assets written to: rsi_above_60_model\assets

# %%
rsi_above_60 = tf.keras.models.load_model('rsi_above_60_model/')

# %%
rsi_below_40 = tf.keras.models.load_model('rsi_below_60_model/')

# %%
macd_below_0 = tf.keras.models.load_model('macd_below_0_model')

# %% [markdown]
# TESTING WITH SQ

# %%
stock_dict = {}

stocks = ['SQ']
for stock in stocks:
    r = requests.get(f"https://finance.yahoo.com/quote/{stock}/history?period1=1459296000&period2=1617062400&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true")
    soup = bs(r.content)
    scripts = soup.find_all('script')
    pr = str(scripts[52]).split('root.App.main = ')[1]
    pr = pr.split(';\n}(this));\n</script>')[0]
    fin_data = json.loads(pr)
    new_df = pd.DataFrame(fin_data['context']['dispatcher']['stores']['HistoricalPriceStore']['prices'])
    if 'type' in new_df.columns:
        new_df = new_df[new_df['type']!='DIVIDEND']
    new_df.sort_values('date', inplace=True)
    new_df.reset_index(inplace=True)
    new_df.drop('index',axis=1,inplace=True)
    stock_dict[stock] = new_df
    
for stock in stock_dict:
    df = stock_dict[stock]
    df.reset_index(inplace=True)
    df['change'] = df['close'] - df['close'].shift(1)
    df['ema_26'] = df['close'].ewm(span=26).mean()
    df['ema_12'] = df['close'].ewm(span=12).mean()
    df['macd'] = df['ema_26'] - df['ema_12']
    df['signal'] = df['macd'].ewm(span=9).mean()
    df['gain'] = df.apply(gain, axis = 1)
    df['loss'] = df.apply(loss, axis = 1)
    df['avg_gain'] = df['gain'].rolling(14).mean()
    df['avg_loss'] = df['loss']. rolling(14).mean()
    df['prev_avg_gain'] = df['avg_gain'].shift(1)
    df['prev_avg_loss'] = df['avg_loss'].shift(1)
    df['ma_20'] = df['close'].rolling(20).mean()
    df['ma_9'] = df['close'].rolling(9).mean()
    df['ma_50'] = df['close'].rolling(50).mean()
    df['14_min'] = df['low'].rolling(14).min()
    df['14_max'] = df['high'].rolling(14).max()
    df['stdev'] = abs(df['close'].rolling(20).std())
    df['upperband'] = df['ma_20'] + (df['stdev']*2)
    df['lowerband'] = df['ma_20'] - (df['stdev']*2)
    df['future_max_30'] = df.apply(future_max_price,axis=1)
    df['future_min_30'] = df.apply(future_min_price,axis=1)
    df['max_change'] = df['future_max_30'] - df['close']
    df['min_change'] = df['future_min_30'] - df['close']
    df['stochastic'] = df.apply(stochastic, axis = 1)
    df['rsi'] = df.apply(rsi, axis = 1)
    
    for i in df.index[26:-10]:
        end = i
        fig, ax = plt.subplots()
        ax.plot(df.loc[end-20:end]['index'], df.loc[end-20:end]['macd'], color = 'blue', linewidth = 4)
        ax.plot(df.loc[end-20:end]['index'], df.loc[end-20:end]['signal'], color = 'green', linewidth = 4)
        ax.axhline(y=0, color = 'black', linewidth = 4)

        if df.iloc[end]['max_change']/df.iloc[end]['close'] > .05 and df.iloc[end]['min_change']/df.iloc[end]['close'] >-.025 and df.iloc[end]['macd'] < 0:
            target = 'macd_20_day/gain'
        elif df.iloc[end]['min_change']/df.iloc[end]['close'] <-.05 and df.iloc[end]['max_change']/df.iloc[end]['close'] <.025 and df.iloc[end]['macd'] < 0:
            target = 'macd_20_day/loss'
        else:
            plt.close(fig)
            continue
        ax.axis('off')
        fig.savefig(f'{target}/{stock}_{end}_macd.jpeg')
        plt.close(fig)
# Out:
# <ipython-input-10-2a704b200d94>:32: RuntimeWarning: divide by zero encountered in double_scalars
#   return 100 - (100 / (1+((row['prev_avg_gain']*13)+row['gain'])/-((row['prev_avg_loss']*13)+row['loss'])))

# %%
gains = []
losses = []
for i in os.listdir('macd_20_day/gain/'):
    
    if 'SQ' in i:

        img = keras.preprocessing.image.load_img(
            f"macd_20_day/gain/{i}", target_size=(img_height, img_width)
        )
        img_array = keras.preprocessing.image.img_to_array(img)
        img_array = tf.expand_dims(img_array, 0) # Create a batch

        predictions = macd_below_0.predict(img_array)
        score = tf.nn.softmax(predictions[0])

        print(i,
            "This image most likely belongs to {} with a {:.2f} percent confidence."
            .format(class_names[np.argmax(score)], 100 * np.max(score))
        )
        if class_names[np.argmax(score)] == 'gain' and np.max(score)>.90:
            gains.append(i)
        elif class_names[np.argmax(score)] == 'loss' and np.max(score)>.90:
            losses.append(i)
# Out:
# SQ_100_macd.jpeg This image most likely belongs to loss with a 98.57 percent confidence.
# SQ_101_macd.jpeg This image most likely belongs to gain with a 99.98 percent confidence.
# SQ_1022_macd.jpeg This image most likely belongs to loss with a 99.33 percent confidence.
# SQ_1023_macd.jpeg This image most likely belongs to gain with a 99.81 percent confidence.
# SQ_1024_macd.jpeg This image most likely belongs to loss with a 93.43 percent confidence.
# SQ_1025_macd.jpeg This image most likely belongs to loss with a 52.11 percent confidence.
# SQ_1027_macd.jpeg This image most likely belongs to gain with a 89.28 percent confidence.
# SQ_1031_macd.jpeg This image most likely belongs to gain with a 98.28 percent confidence.
# SQ_1032_macd.jpeg This image most likely belongs to gain with a 92.82 percent confidence.
# SQ_1033_macd.jpeg This image most likely belongs to loss with a 92.90 percent confidence.
# ...

# %%
len(gains)
# Out:
# 144

# %%
len(losses)
# Out:
# 82

# %%
np.max(score)
# Out:
# 0.9996916

# %%
len(gains)/(len(gains)+len(losses))
# Out:
# 0.6371681415929203

# %%
plt.plot(stock_dict['AAPL'].index, stock_dict['AAPL']['macd'])
plt.plot(stock_dict['AAPL'].index, stock_dict['AAPL']['signal'])
