# %%
import pandas as pd
import datetime
import numpy as np
import csv
import matplotlib.pyplot as plt
# %matplotlib inline

api_key = 'sk_f491c9326e6a4b79a7ed5b1689c178f3'

master_spy_df = pd.read_csv('master_spy_data.csv',index_col=0)

# %%
dec_df = master_spy_df[0:360]

# %%
dec_df['prices'].plot()

# %%
m,b = np.polyfit(range(0,len(dec_df)),dec_df['prices'],1)

# %%
# Out:
# 0.0012955253512751841
